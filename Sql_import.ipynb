# %% [markdown]
# **SQL DATASPARK**

# %% [markdown]
# *CUSTOMERS*

# %%
import mysql.connector
import pandas as pd

# %%
conn = mysql.connector.connect(
    host='localhost',  
    user='root', 
    password='20022004@Yuva', 
    database='global_electronics'  
)

cursor = conn.cursor()

if conn.is_connected():
    print("Successfully connected to the database.")
# Out:
# Successfully connected to the database.

# %%
customers_df = pd.read_csv(r"C:\Users\navee\OneDrive\Desktop\DATA_SPARK(project-2)\cleanes_customers")

for index, row in customers_df.iterrows():
    sql = """INSERT INTO customers (customer_key, gender, name, city, state_code, state, zip_code, country, continent, birthdate, age)
             VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"""
    val = (row['CustomerKey'], row['Gender'], row['Name'], row['City'], row['State Code'], 
           row['State'], row['Zip Code'], row['Country'], row['Continent'], row['Birthday'], row['Age'])
    cursor.execute(sql, val)

conn.commit()

# %%
cursor.fetchall()
cursor.execute("SELECT * FROM customers")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (301, 'Female', 'Lilly Harding', 'WANDEARAH EAST', 'SA', 'South Australia', '5523', 'Australia', 'Australia', datetime.date(1939, 7, 3), 85)
# (325, 'Female', 'Madison Hull', 'MOUNT BUDD', 'WA', 'Western Australia', '6522', 'Australia', 'Australia', datetime.date(1979, 9, 27), 45)
# (554, 'Female', 'Claire Ferres', 'WINJALLOK', 'VIC', 'Victoria', '3380', 'Australia', 'Australia', datetime.date(1947, 5, 26), 77)
# (786, 'Male', 'Jai Poltpalingada', 'MIDDLE RIVER', 'SA', 'South Australia', '5223', 'Australia', 'Australia', datetime.date(1957, 9, 17), 67)
# (1042, 'Male', 'Aidan Pankhurst', 'TAWONGA SOUTH', 'VIC', 'Victoria', '3698', 'Australia', 'Australia', datetime.date(1965, 11, 19), 58)
# (1086, 'Male', 'Hayden Clegg', 'TEMPLERS', 'SA', 'South Australia', '5371', 'Australia', 'Australia', datetime.date(1954, 1, 20), 70)
# (1133, 'Male', 'Nicholas Caffyn', 'JUBILEE POCKET', 'QLD', 'Queensland', '4802', 'Australia', 'Australia', datetime.date(1969, 11, 22), 54)
# ...

# %% [markdown]
# *PRODUCT*

# %%
ProductS_df = pd.read_csv(r"C:\Users\navee\OneDrive\Desktop\DATA_SPARK(project-2)\cleaned_products.csv")

for index, row in ProductS_df.iterrows():
    sql = """INSERT INTO products (product_key, product_name, brand, color, unit_cost_usd, unit_price_usd, subcategory_key, subcategory, category_key, category)
             VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"""
    val = (
        row['ProductKey'], 
        row['Product Name'], 
        row['Brand'], 
        row['Color'], 
        row['Unit Cost USD'], 
        row['Unit Price USD'], 
        row['SubcategoryKey'], 
        row['Subcategory'], 
        row['CategoryKey'], 
        row['Category']
    )
    cursor.execute(sql, val)

conn.commit()

# %% [markdown]
# *STORES*

# %%
stores_df = pd.read_csv(r"C:\Users\navee\OneDrive\Desktop\DATA_SPARK(project-2)\cleaned_stores.csv")

for index, row in stores_df.iterrows():
    sql = """INSERT INTO stores (store_key, country, state, square_meters, open_date, store_age)
             VALUES (%s, %s, %s, %s, %s, %s)"""
    val = (
        row['StoreKey'], 
        row['Country'], 
        row['State'], 
        row['Square Meters'], 
        row['Open Date'], 
        row['Store Age']
    )
    cursor.execute(sql, val)

conn.commit()

# %% [markdown]
# *SALES*

# %%
sales_df = pd.read_csv(r"C:\Users\navee\OneDrive\Desktop\DATA_SPARK(project-2)\Sales_cleaned.csv")

for index, row in sales_df.iterrows():
    sql = """INSERT INTO sales (order_number, line_item, order_date, customer_key, store_key, product_key, quantity, currency_code)
             VALUES (%s, %s, %s, %s, %s, %s, %s, %s)"""
    val = (
        row['Order Number'], 
        row['Line Item'], 
        row['Order Date'], 
        row['CustomerKey'], 
        row['StoreKey'], 
        row['ProductKey'], 
        row['Quantity'], 
        row['Currency Code']
    )
    cursor.execute(sql, val)
    
    
conn.commit()

# %% [markdown]
# *EXCHANGE RATES*

# %%
exchange_rate_df = pd.read_csv(r"C:\Users\navee\OneDrive\Desktop\DATA_SPARK(project-2)\cleaned_exchange_rate_data.csv")

# %%
print(exchange_rate_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  datetime64[ns]
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 263.0+ KB
# None

# %%
from datetime import datetime
exchange_rate_df['Date'] = pd.to_datetime(exchange_rate_df['Date'])

# %%
for index, row in exchange_rate_df.iterrows():
    sql = """INSERT INTO exchange_rates (exchange_date, currency, exchange_rate)
             VALUES (%s, %s, %s)"""
    val = (
        row['Date'], 
        row['Currency'],  
        row['Exchange']  
    )
    cursor.execute(sql, val)

conn.commit()
